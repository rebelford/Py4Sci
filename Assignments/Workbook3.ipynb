# %% [markdown]
# # Workbook 3:
#
# ## Part 1
# Create a tool that uses the solubility rules to determine if a salt is soluble in water. There are many ways you can do this. You are also welcome to use the names instead of the formulas, but you will need to provide instructions. Now there are many ways to do this and I am sure the AIs can show you several different ones.
#
#
# ![image.png](attachment:bab59cc5-7ce1-4632-895e-26163daba7d7.png)
# **Due Sunday at midnight, February 16, 2025**

# %% [markdown]
# It might be easiest to start with an input function that asks for the cation and then the anion, like:

# %%
cation = input("Please enter the name of the cation.")
anion = input("Please enter the name of the anion.")
#your code goes here
print(f'A salt between {cation} and {anion} is [your answer]')
# Out:
# Please enter the name of the cation. barium
# Please enter the name of the anion. sulfate
# A salt between barium and sulfate is [your answer]

# %% [markdown]
# ## Part 2
# Explain your code and how it works,  this should be a line by line explanation, and the AI can help.  You are welcome to use multiple markdown and code cells.
